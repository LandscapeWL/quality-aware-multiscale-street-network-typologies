# %% [markdown]
# # 04_Download Facilities and Quality History Data
#
# This step downloads and prepares three datasets: Overture Places, OSM facility POIs, and ohsome annual quality history. The main entry point is `download_facilities_quality_history.py` in this directory, and it supports resumable runs.

# %%
from pathlib import Path
import sys

ROOT = Path('/Volumes/ZHITAI2T/202606osm')
CODE_DIR = ROOT / 'code_upload/04_download_facilities_quality_history_data'
DATA_DIR = ROOT / 'data/04_download_facilities_quality_history_data'
SCRIPT = CODE_DIR / 'download_facilities_quality_history.py'
PYTHON = sys.executable

print('python:', PYTHON)
print('script:', SCRIPT)
print('data:', DATA_DIR)

# %% [markdown]
# Background runs start the three task types separately. Logs are written to `data/04_download_facilities_quality_history_data/logs/`, and status tables are written to `data/04_download_facilities_quality_history_data/status/`.

# %%
# Check progress
# !{PYTHON} {SCRIPT} --only status

# %%
# To run all tasks sequentially in the foreground, uncomment the next line.
# !{PYTHON} {SCRIPT} --only all
