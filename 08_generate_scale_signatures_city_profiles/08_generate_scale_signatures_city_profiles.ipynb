# %% [markdown]
# # 08_generate_scale_signatures_city_profiles
#
# This notebook is a lightweight entry point for the formal processing step; inputs, outputs, and execution order follow docs/PLAN.md.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path('/Volumes/ZHITAI2T/202606osm')

# %%
# Current step: 08_generate_scale_signatures_city_profiles
# Upstream standard outputs are connected here; the current implementation uses a flat step directory.
data_dir = ROOT / 'data/08_generate_scale_signatures_city_profiles'
print(data_dir)
children = sorted(p.name for p in data_dir.iterdir() if not p.name.startswith('.')) if data_dir.exists() else []
print('children:', children)
