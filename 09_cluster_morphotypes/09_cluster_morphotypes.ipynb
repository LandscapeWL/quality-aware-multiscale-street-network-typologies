# %% [markdown]
# # 09_cluster_morphotypes
#
# The reproducible entry point is `step09_cluster_morphotypes.py`. This notebook only keeps a lightweight entry point and output check, avoiding a second clustering implementation.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path('/Volumes/ZHITAI2T/202606osm')

# %%
# Current step: 09_cluster_morphotypes
script_path = ROOT / 'code_upload/09_cluster_morphotypes/step09_cluster_morphotypes.py'
data_dir = ROOT / 'data/09_cluster_morphotypes'
print('script:', script_path)
print(data_dir)
children = sorted(p.name for p in data_dir.iterdir() if not p.name.startswith('.')) if data_dir.exists() else []
print('children:', children)
