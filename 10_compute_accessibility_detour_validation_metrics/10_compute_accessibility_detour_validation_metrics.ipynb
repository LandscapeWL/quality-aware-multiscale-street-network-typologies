# %% [markdown]
# # 10_compute_accessibility_detour_validation_metrics
#
# The main logic is implemented in `step10_accessibility_detour.py`. This notebook keeps only a minimal entry point to avoid maintaining duplicate analysis logic inside the notebook.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path('/Volumes/ZHITAI2T/202606osm')

# %%
# Current step: 10_compute_accessibility_detour_validation_metrics
# Pilot: main_030, main_070, chn_003, chn_004; 300 origins x 4 destinations.
# Full main run: add --mode main --overwrite when ready for all 48 main_fit cities.
script = ROOT / 'code_upload/10_compute_accessibility_detour_validation_metrics/step10_accessibility_detour.py'
data_dir = ROOT / 'data/10_compute_accessibility_detour_validation_metrics'
print('script:', script)
print(data_dir)
children = sorted(p.name for p in data_dir.iterdir() if not p.name.startswith('.')) if data_dir.exists() else []
print('children:', children)
