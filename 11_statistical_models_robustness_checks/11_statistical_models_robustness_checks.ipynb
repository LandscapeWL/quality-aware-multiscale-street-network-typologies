# %% [markdown]
# # 11_statistical_models_robustness_checks
#
# The main logic is in `step11_model_robustness.py`. This notebook keeps only a minimal entry point to avoid duplicating statistical modeling logic in an interactive environment.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path('/Volumes/ZHITAI2T/202606osm')

# %%
# Current step: 11_statistical_models_robustness_checks
# Use the script for formal execution; outputs are written to data/11_statistical_models_robustness_checks.
data_dir = ROOT / 'data/11_statistical_models_robustness_checks'
script = ROOT / 'code_upload/11_statistical_models_robustness_checks/step11_model_robustness.py'
print(script)
print(data_dir)
children = sorted(p.name for p in data_dir.iterdir() if not p.name.startswith('.')) if data_dir.exists() else []
print('children:', children)
