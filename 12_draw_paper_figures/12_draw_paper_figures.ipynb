# %% [markdown]
# # 12_draw_paper_figures
#
# This notebook is a scaffold for later formal processing steps; inputs, outputs, and execution order follow docs/PLAN.md.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path('/Volumes/ZHITAI2T/202606osm')

# %%
# Current step: 12_draw_paper_figures
# Future implementation will connect upstream standardized outputs here; the current implementation uses flat step directories to avoid duplicate nesting.
data_dir = ROOT / 'data/12_draw_paper_figures'
print(data_dir)
children = sorted(p.name for p in data_dir.iterdir() if not p.name.startswith('.')) if data_dir.exists() else []
print('children:', children)
