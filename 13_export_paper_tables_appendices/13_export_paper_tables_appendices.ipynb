# %% [markdown]
# # 13_export_paper_tables_appendices
#
# This notebook is a skeleton for the formal processing step; inputs, outputs, and execution order follow docs/PLAN.md.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path('/Volumes/ZHITAI2T/202606osm')

# %%
# Current step: 13_export_paper_tables_appendices
# Future work will connect upstream standard outputs here; the current implementation uses a flat step directory to avoid duplicate nesting.
data_dir = ROOT / 'data/13_export_paper_tables_appendices'
print(data_dir)
children = sorted(p.name for p in data_dir.iterdir() if not p.name.startswith('.')) if data_dir.exists() else []
print('children:', children)
